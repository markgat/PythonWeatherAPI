# %% [markdown]
# # WeatherPy
# ----

# %% [markdown]
# ### Observations
#
#    1) Firstly, we can see within the latitude versus temperature plot that higher max temperatures are centralized towards the center at 0 latitude (the equator). This goes hand-in-hand with our guess that it is warmer near the equator.
#
#    2) Secondly, within our latitude versus humidity plot, we see a higher average of humidity percentage near the equator; humidity makes it difficult for heat to transfer away via evaporation. This makes it feel warmer.
#
#    3) Lastly, on our latitude versus cloudiness plot, we see a lesser concentration of 0% cloudiness near the equator. Clouds are formed with water vapours rising by heat.

# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
from datetime import datetime

# Import API key
from api_keys import api_key

# Incorporated citipy to determine city based on latitude and longitude
from citipy import citipy

# Output File (CSV)
output_data_file = "output_data/cities.csv"

# Range of latitudes and longitudes
lat_range = (-90, 90)
lng_range = (-180, 180)

# %% [markdown]
# ## Generate Cities List

# %%
# List for holding lat_lngs and cities
lat_lngs = []
cities = []

# Create a set of random lat and lng combinations
lats = np.random.uniform(low=-90.000, high=90.000, size=1500)
lngs = np.random.uniform(low=-180.000, high=180.000, size=1500)
lat_lngs = zip(lats, lngs)

# Identify nearest city for each lat, lng combination
for lat_lng in lat_lngs:
    city = citipy.nearest_city(lat_lng[0], lat_lng[1]).city_name
    
    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)

# Print the city count to confirm sufficient count
len(cities)
# Out:
# 611

# %% [markdown]
# ### Perform API Calls
# * Perform a weather check on each city using a series of successive API calls.
# * Include a print log of each city as it'sbeing processed (with the city number and city name).

# %%
url = "https://api.openweathermap.org/data/2.5/weather?"
print('''Begin Data Retrieval
-----------------------------''')
record = 1
setnum = 1
ct = []
cloud = []
country = []
dt = []
hum = []
lat =[]
lng = []
maxt = []
winsp = []
for citi in cities:
    if record != 51:
        response = requests.get(url,params={'q': citi, 'APPID':api_key, 'units': 'imperial'}).json()
        try:
            print(f"Processing Record {record} of Set {setnum} | {response['name']}")
            record += 1
            ct.append(citi)
            cloud.append(response['clouds']['all'])
            country.append(response['sys']['country'])
            dt.append(response['dt'])
            hum.append(response['main']['humidity'])
            lat.append(response['coord']['lat'])
            lng.append(response['coord']['lon'])
            maxt.append(response['main']['temp_max'])
            winsp.append(response['wind']['speed'])
        except:
            print('City not found. Skipping...')
    else:
        record = 1
        setnum += 1
# Out:
# Begin Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | Busselton
# Processing Record 2 of Set 1 | Bethel
# Processing Record 3 of Set 1 | Katima Mulilo
# Processing Record 4 of Set 1 | Sola
# Processing Record 5 of Set 1 | Saskylakh
# Processing Record 6 of Set 1 | East London
# Processing Record 7 of Set 1 | Samfya
# Processing Record 8 of Set 1 | New Norfolk
# Processing Record 9 of Set 1 | Puerto Ayora
# Processing Record 10 of Set 1 | Yellowknife
# Processing Record 11 of Set 1 | Ribeira Grande
# Processing Record 12 of Set 1 | Hobyo
# Processing Record 13 of Set 1 | Oktyabrskoye
# Processing Record 14 of Set 1 | Ballitoville
# Processing Record 15 of Set 1 | Avarua
# Processing Record 16 of Set 1 | Hambantota
# City not found. Skipping...
# Processing Record 17 of Set 1 | Labuhan
# Processing Record 18 of Set 1 | Hermanus
# Processing Record 19 of Set 1 | Albany
# Processing Record 20 of Set 1 | Dingle
# Processing Record 21 of Set 1 | Lompoc
# City not found. Skipping...
# Processing Record 22 of Set 1 | Manokwari
# Processing Record 23 of Set 1 | Ponta do Sol
# Processing Record 24 of Set 1 | Qaqortoq
# Processing Record 25 of Set 1 | Collie
# Processing Record 26 of Set 1 | Tiksi
# Processing Record 27 of Set 1 | Rikitea
# City not found. Skipping...
# Processing Record 28 of Set 1 | San Cristobal
# Processing Record 29 of Set 1 | Angoram
# Processing Record 30 of Set 1 | Carnarvon
# Processing Record 31 of Set 1 | Georgetown
# Processing Record 32 of Set 1 | Rome
# Processing Record 33 of Set 1 | Kaitangata
# Processing Record 34 of Set 1 | Chokurdakh
# Processing Record 35 of Set 1 | Thurso
# Processing Record 36 of Set 1 | Lebu
# Processing Record 37 of Set 1 | Nowy Dwor Gdanski
# Processing Record 38 of Set 1 | Atuona
# Processing Record 39 of Set 1 | Nago
# Processing Record 40 of Set 1 | Campoalegre
# City not found. Skipping...
# Processing Record 41 of Set 1 | College
# Processing Record 42 of Set 1 | Chiapa
# Processing Record 43 of Set 1 | Hobart
# Processing Record 44 of Set 1 | Port Blair
# Processing Record 45 of Set 1 | Mankono
# Processing Record 46 of Set 1 | Xiaoweizhai
# Processing Record 47 of Set 1 | Khuzhir
# Processing Record 48 of Set 1 | Cherskiy
# Processing Record 49 of Set 1 | Barrow
# Processing Record 50 of Set 1 | Thompson
# Processing Record 1 of Set 2 | Mandalgovi
# Processing Record 2 of Set 2 | Ushuaia
# Processing Record 3 of Set 2 | Charlestown
# Processing Record 4 of Set 2 | Butaritari
# Processing Record 5 of Set 2 | Yulara
# Processing Record 6 of Set 2 | Esperance
# Processing Record 7 of Set 2 | Jamestown
# Processing Record 8 of Set 2 | Ulaangom
# Processing Record 9 of Set 2 | Moron
# Processing Record 10 of Set 2 | Bathsheba
# Processing Record 11 of Set 2 | Komsomolskiy
# Processing Record 12 of Set 2 | Takoradi
# Processing Record 13 of Set 2 | Lermontovka
# Processing Record 14 of Set 2 | Castelo Branco
# Processing Record 15 of Set 2 | Qaanaaq
# Processing Record 16 of Set 2 | Santa Rosalia
# Processing Record 17 of Set 2 | Magdagachi
# Processing Record 18 of Set 2 | Vardo
# Processing Record 19 of Set 2 | Mataura
# Processing Record 20 of Set 2 | Hilo
# Processing Record 21 of Set 2 | Hasaki
# Processing Record 22 of Set 2 | Mahebourg
# Processing Record 23 of Set 2 | Ust-Karsk
# Processing Record 24 of Set 2 | Okha
# Processing Record 25 of Set 2 | Tazovskiy
# Processing Record 26 of Set 2 | Cape Town
# Processing Record 27 of Set 2 | Forbes
# Processing Record 28 of Set 2 | Dargaville
# Processing Record 29 of Set 2 | Kapaa
# City not found. Skipping...
# Processing Record 30 of Set 2 | La Palma
# Processing Record 31 of Set 2 | Harlingen
# City not found. Skipping...
# Processing Record 32 of Set 2 | Arraial do Cabo
# Processing Record 33 of Set 2 | Punta Arenas
# Processing Record 34 of Set 2 | Constitucion
# Processing Record 35 of Set 2 | Kerur
# Processing Record 36 of Set 2 | Shimoda
# Processing Record 37 of Set 2 | Opuwo
# Processing Record 38 of Set 2 | Gimli
# Processing Record 39 of Set 2 | Muros
# Processing Record 40 of Set 2 | Luanda
# Processing Record 41 of Set 2 | Bredasdorp
# Processing Record 42 of Set 2 | Lana
# Processing Record 43 of Set 2 | Hithadhoo
# Processing Record 44 of Set 2 | Codrington
# City not found. Skipping...
# Processing Record 45 of Set 2 | Yuzhno-Sukhokumsk
# City not found. Skipping...
# Processing Record 46 of Set 2 | Port Hedland
# Processing Record 47 of Set 2 | Cork
# Processing Record 48 of Set 2 | Sao Filipe
# Processing Record 49 of Set 2 | Akureyri
# Processing Record 50 of Set 2 | Calatayud
# Processing Record 1 of Set 3 | Mumford
# Processing Record 2 of Set 3 | Seaford
# Processing Record 3 of Set 3 | Saint-Philippe
# Processing Record 4 of Set 3 | Dunedin
# Processing Record 5 of Set 3 | Henties Bay
# Processing Record 6 of Set 3 | Torbay
# Processing Record 7 of Set 3 | Quesnel
# City not found. Skipping...
# Processing Record 8 of Set 3 | Mar del Plata
# City not found. Skipping...
# Processing Record 9 of Set 3 | Jiuquan
# Processing Record 10 of Set 3 | Aripuana
# Processing Record 11 of Set 3 | Alexandria
# Processing Record 12 of Set 3 | Klaksvik
# Processing Record 13 of Set 3 | Bayir
# City not found. Skipping...
# Processing Record 14 of Set 3 | Iturama
# Processing Record 15 of Set 3 | Kodiak
# Processing Record 16 of Set 3 | Saint-Leu
# Processing Record 17 of Set 3 | Bluff
# Processing Record 18 of Set 3 | Meulaboh
# Processing Record 19 of Set 3 | Port Elizabeth
# Processing Record 20 of Set 3 | Longyearbyen
# Processing Record 21 of Set 3 | Puerto Maldonado
# Processing Record 22 of Set 3 | Seidu
# City not found. Skipping...
# Processing Record 23 of Set 3 | Jieshou
# Processing Record 24 of Set 3 | Jalpan
# Processing Record 25 of Set 3 | Gushikawa
# Processing Record 26 of Set 3 | Caravelas
# Processing Record 27 of Set 3 | Khandyga
# Processing Record 28 of Set 3 | Sechura
# Processing Record 29 of Set 3 | Vaini
# Processing Record 30 of Set 3 | Ugoofaaru
# Processing Record 31 of Set 3 | Norman Wells
# City not found. Skipping...
# Processing Record 32 of Set 3 | Mount Isa
# Processing Record 33 of Set 3 | Dhidhdhoo
# Processing Record 34 of Set 3 | Narsaq
# City not found. Skipping...
# Processing Record 35 of Set 3 | Kargasok
# City not found. Skipping...
# Processing Record 36 of Set 3 | Port Moresby
# Processing Record 37 of Set 3 | Stony Plain
# Processing Record 38 of Set 3 | Zelenogorskiy
# Processing Record 39 of Set 3 | Airai
# Processing Record 40 of Set 3 | Laguna
# Processing Record 41 of Set 3 | Margate
# Processing Record 42 of Set 3 | Mandan
# Processing Record 43 of Set 3 | Tikrit
# City not found. Skipping...
# Processing Record 44 of Set 3 | Tisovec
# Processing Record 45 of Set 3 | Lata
# Processing Record 46 of Set 3 | Tuktoyaktuk
# Processing Record 47 of Set 3 | Keti Bandar
# Processing Record 48 of Set 3 | Tekari
# Processing Record 49 of Set 3 | Port Lincoln
# Processing Record 50 of Set 3 | Bambous Virieux
# Processing Record 1 of Set 4 | Upernavik
# Processing Record 2 of Set 4 | Parana
# Processing Record 3 of Set 4 | Trairi
# Processing Record 4 of Set 4 | Namibe
# City not found. Skipping...
# Processing Record 5 of Set 4 | Kahului
# Processing Record 6 of Set 4 | Bacolod
# Processing Record 7 of Set 4 | Dom Pedrito
# Processing Record 8 of Set 4 | Araouane
# Processing Record 9 of Set 4 | Usinsk
# Processing Record 10 of Set 4 | North Bend
# Processing Record 11 of Set 4 | Cockburn Town
# Processing Record 12 of Set 4 | San Patricio
# Processing Record 13 of Set 4 | Hami
# Processing Record 14 of Set 4 | Victoria
# Processing Record 15 of Set 4 | Oranjestad
# Processing Record 16 of Set 4 | Gornopravdinsk
# Processing Record 17 of Set 4 | Turukhansk
# Processing Record 18 of Set 4 | Porbandar
# Processing Record 19 of Set 4 | LOS ALGARROBOS
# Processing Record 20 of Set 4 | Marzuq
# Processing Record 21 of Set 4 | Saint George
# Processing Record 22 of Set 4 | Saint-Pierre
# Processing Record 23 of Set 4 | Cidreira
# Processing Record 24 of Set 4 | Lavrentiya
# Processing Record 25 of Set 4 | Port Macquarie
# City not found. Skipping...
# Processing Record 26 of Set 4 | Eureka
# Processing Record 27 of Set 4 | Uusikaupunki
# Processing Record 28 of Set 4 | Praia da Vitoria
# Processing Record 29 of Set 4 | Souillac
# Processing Record 30 of Set 4 | Ishigaki
# Processing Record 31 of Set 4 | Leningradskiy
# Processing Record 32 of Set 4 | The Pas
# Processing Record 33 of Set 4 | Khatanga
# Processing Record 34 of Set 4 | Ancud
# Processing Record 35 of Set 4 | Maragogi
# Processing Record 36 of Set 4 | Taksimo
# Processing Record 37 of Set 4 | Huamachuco
# Processing Record 38 of Set 4 | Avera
# Processing Record 39 of Set 4 | Haines Junction
# Processing Record 40 of Set 4 | Coronado
# Processing Record 41 of Set 4 | Nicoya
# Processing Record 42 of Set 4 | Yeppoon
# Processing Record 43 of Set 4 | Kruisfontein
# Processing Record 44 of Set 4 | Adrar
# Processing Record 45 of Set 4 | Chuy
# Processing Record 46 of Set 4 | Port Hardy
# Processing Record 47 of Set 4 | Grand Gaube
# Processing Record 48 of Set 4 | Shubarkuduk
# Processing Record 49 of Set 4 | Aklavik
# Processing Record 50 of Set 4 | Severo-Kurilsk
# Processing Record 1 of Set 5 | Tigre
# Processing Record 2 of Set 5 | Isangel
# Processing Record 3 of Set 5 | Nuevo Laredo
# Processing Record 4 of Set 5 | Marsh Harbour
# Processing Record 5 of Set 5 | Fort Nelson
# Processing Record 6 of Set 5 | Tasiilaq
# Processing Record 7 of Set 5 | Sinnamary
# Processing Record 8 of Set 5 | Mandeville
# Processing Record 9 of Set 5 | Kununurra
# Processing Record 10 of Set 5 | Mangrol
# Processing Record 11 of Set 5 | Asosa
# Processing Record 12 of Set 5 | Pevek
# Processing Record 13 of Set 5 | Balkhash
# Processing Record 14 of Set 5 | Sitka
# Processing Record 15 of Set 5 | Fuyu
# Processing Record 16 of Set 5 | Sobolevo
# Processing Record 17 of Set 5 | Castro
# Processing Record 18 of Set 5 | Katsuura
# Processing Record 19 of Set 5 | Berlevag
# Processing Record 20 of Set 5 | Dwarka
# Processing Record 21 of Set 5 | Pacific Grove
# Processing Record 22 of Set 5 | Teguise
# Processing Record 23 of Set 5 | Tuatapere
# Processing Record 24 of Set 5 | Whyalla
# Processing Record 25 of Set 5 | Kauhajoki
# Processing Record 26 of Set 5 | Los Llanos de Aridane
# Processing Record 27 of Set 5 | Nome
# Processing Record 28 of Set 5 | Natal
# Processing Record 29 of Set 5 | Saint-Francois
# Processing Record 30 of Set 5 | Nikolskoye
# Processing Record 31 of Set 5 | Iskateley
# Processing Record 32 of Set 5 | Puerto del Rosario
# Processing Record 33 of Set 5 | Provideniya
# Processing Record 34 of Set 5 | Iqaluit
# Processing Record 35 of Set 5 | Bermejo
# Processing Record 36 of Set 5 | Broome
# Processing Record 37 of Set 5 | Ust-Tsilma
# Processing Record 38 of Set 5 | Suining
# Processing Record 39 of Set 5 | Baruun-Urt
# Processing Record 40 of Set 5 | Khorixas
# Processing Record 41 of Set 5 | Sambava
# Processing Record 42 of Set 5 | Poum
# Processing Record 43 of Set 5 | Arman
# Processing Record 44 of Set 5 | Den Helder
# Processing Record 45 of Set 5 | Hamilton
# Processing Record 46 of Set 5 | Faanui
# City not found. Skipping...
# Processing Record 47 of Set 5 | Kande
# Processing Record 48 of Set 5 | Udachnyy
# Processing Record 49 of Set 5 | Tecuala
# Processing Record 50 of Set 5 | Hualmay
# Processing Record 1 of Set 6 | Aranos
# Processing Record 2 of Set 6 | Petropavlovsk-Kamchatskiy
# Processing Record 3 of Set 6 | Liuzhou
# Processing Record 4 of Set 6 | Margherita
# Processing Record 5 of Set 6 | San Juan
# Processing Record 6 of Set 6 | Sabang
# Processing Record 7 of Set 6 | Aloleng
# Processing Record 8 of Set 6 | Lanquin
# Processing Record 9 of Set 6 | Palaikastron
# Processing Record 10 of Set 6 | Touros
# Processing Record 11 of Set 6 | Hofn
# Processing Record 12 of Set 6 | Vila Velha
# Processing Record 13 of Set 6 | Sioux Lookout
# Processing Record 14 of Set 6 | Kavieng
# Processing Record 15 of Set 6 | Ilulissat
# City not found. Skipping...
# Processing Record 16 of Set 6 | Ayr
# City not found. Skipping...
# Processing Record 17 of Set 6 | Buala
# Processing Record 18 of Set 6 | Port Augusta
# Processing Record 19 of Set 6 | Yarim
# Processing Record 20 of Set 6 | Salalah
# Processing Record 21 of Set 6 | Progreso
# City not found. Skipping...
# Processing Record 22 of Set 6 | Daltenganj
# Processing Record 23 of Set 6 | Homer
# Processing Record 24 of Set 6 | Mount Gambier
# Processing Record 25 of Set 6 | Geraldton
# Processing Record 26 of Set 6 | Raudeberg
# Processing Record 27 of Set 6 | Riyadh
# Processing Record 28 of Set 6 | La Romana
# Processing Record 29 of Set 6 | Lebanon
# Processing Record 30 of Set 6 | Lethem
# Processing Record 31 of Set 6 | Waipawa
# Processing Record 32 of Set 6 | Luau
# Processing Record 33 of Set 6 | Pilar
# Processing Record 34 of Set 6 | Gidole
# Processing Record 35 of Set 6 | Vestmannaeyjar
# Processing Record 36 of Set 6 | Comodoro Rivadavia
# Processing Record 37 of Set 6 | Nanortalik
# Processing Record 38 of Set 6 | Iseyin
# Processing Record 39 of Set 6 | Ipinda
# Processing Record 40 of Set 6 | Pouso Alegre
# Processing Record 41 of Set 6 | Salvador
# Processing Record 42 of Set 6 | Taicheng
# Processing Record 43 of Set 6 | Kupang
# Processing Record 44 of Set 6 | Batemans Bay
# Processing Record 45 of Set 6 | Goderich
# City not found. Skipping...
# Processing Record 46 of Set 6 | Belmonte
# Processing Record 47 of Set 6 | Agadir
# Processing Record 48 of Set 6 | Kikwit
# Processing Record 49 of Set 6 | devin
# Processing Record 50 of Set 6 | Bundaberg
# Processing Record 1 of Set 7 | Burgstadt
# Processing Record 2 of Set 7 | Fairbanks
# Processing Record 3 of Set 7 | Tual
# Processing Record 4 of Set 7 | Namatanai
# Processing Record 5 of Set 7 | Shimanovsk
# Processing Record 6 of Set 7 | San Quintin
# Processing Record 7 of Set 7 | Smolyaninovo
# Processing Record 8 of Set 7 | Luderitz
# Processing Record 9 of Set 7 | Safranbolu
# Processing Record 10 of Set 7 | Ixtapa
# City not found. Skipping...
# Processing Record 11 of Set 7 | Los Zacatones
# Processing Record 12 of Set 7 | Sergeyevka
# Processing Record 13 of Set 7 | Havelock
# Processing Record 14 of Set 7 | Blankenberge
# Processing Record 15 of Set 7 | Iranshahr
# Processing Record 16 of Set 7 | Rawson
# Processing Record 17 of Set 7 | Trincomalee
# Processing Record 18 of Set 7 | Mariinsk
# Processing Record 19 of Set 7 | Freeport
# Processing Record 20 of Set 7 | Kaoma
# Processing Record 21 of Set 7 | Kyren
# Processing Record 22 of Set 7 | Maniitsoq
# Processing Record 23 of Set 7 | Terra Nova
# Processing Record 24 of Set 7 | Ambilobe
# Processing Record 25 of Set 7 | Yar-Sale
# Processing Record 26 of Set 7 | Pangnirtung
# Processing Record 27 of Set 7 | Hay River
# Processing Record 28 of Set 7 | Tete
# Processing Record 29 of Set 7 | Macusani
# Processing Record 30 of Set 7 | Yaan
# Processing Record 31 of Set 7 | Ozu
# City not found. Skipping...
# City not found. Skipping...
# Processing Record 32 of Set 7 | Cabo San Lucas
# Processing Record 33 of Set 7 | Zhongshu
# Processing Record 34 of Set 7 | Yangambi
# Processing Record 35 of Set 7 | Chumikan
# Processing Record 36 of Set 7 | Suoyarvi
# Processing Record 37 of Set 7 | Tabas
# Processing Record 38 of Set 7 | Atar
# City not found. Skipping...
# Processing Record 39 of Set 7 | Ponta Delgada
# Processing Record 40 of Set 7 | Pingliang
# Processing Record 41 of Set 7 | Pavagada
# Processing Record 42 of Set 7 | Lexington
# Processing Record 43 of Set 7 | Nokaneng
# Processing Record 44 of Set 7 | Kirksville
# Processing Record 45 of Set 7 | Vaitape
# Processing Record 46 of Set 7 | General Pico
# Processing Record 47 of Set 7 | Deputatskiy
# Processing Record 48 of Set 7 | Padang
# Processing Record 49 of Set 7 | Yumen
# Processing Record 50 of Set 7 | Eyrarbakki
# Processing Record 1 of Set 8 | Yerofey Pavlovich
# City not found. Skipping...
# Processing Record 2 of Set 8 | Svetlogorsk
# Processing Record 3 of Set 8 | Bereda
# Processing Record 4 of Set 8 | Sao Felix do Xingu
# Processing Record 5 of Set 8 | Tautira
# Processing Record 6 of Set 8 | Koani
# Processing Record 7 of Set 8 | Gusau
# Processing Record 8 of Set 8 | Alekseyevsk
# Processing Record 9 of Set 8 | Viransehir
# Processing Record 10 of Set 8 | Garowe
# Processing Record 11 of Set 8 | Outlook
# City not found. Skipping...
# Processing Record 12 of Set 8 | Iwanai
# Processing Record 13 of Set 8 | Nizwa
# Processing Record 14 of Set 8 | Aksarka
# Processing Record 15 of Set 8 | Tocok
# Processing Record 16 of Set 8 | Harper
# Processing Record 17 of Set 8 | Beloha
# Processing Record 18 of Set 8 | Kitimat
# Processing Record 19 of Set 8 | Saint-Georges
# City not found. Skipping...
# Processing Record 20 of Set 8 | Melilla
# Processing Record 21 of Set 8 | Richards Bay
# Processing Record 22 of Set 8 | Kamenka
# City not found. Skipping...
# Processing Record 23 of Set 8 | Tessalit
# Processing Record 24 of Set 8 | Mujiayingzi
# Processing Record 25 of Set 8 | Yuxia
# Processing Record 26 of Set 8 | Liverpool
# Processing Record 27 of Set 8 | Rocha
# Processing Record 28 of Set 8 | Portland
# Processing Record 29 of Set 8 | Sao Joao da Barra
# Processing Record 30 of Set 8 | Russell
# Processing Record 31 of Set 8 | Roseto degli Abruzzi
# Processing Record 32 of Set 8 | Awbari
# Processing Record 33 of Set 8 | Witbank
# Processing Record 34 of Set 8 | Karratha
# City not found. Skipping...
# Processing Record 35 of Set 8 | Jumla
# Processing Record 36 of Set 8 | Dalvik
# Processing Record 37 of Set 8 | Helong
# Processing Record 38 of Set 8 | Antofagasta
# Processing Record 39 of Set 8 | Linxi
# Processing Record 40 of Set 8 | Conceicao da Barra
# City not found. Skipping...
# City not found. Skipping...
# Processing Record 41 of Set 8 | Aspindza
# Processing Record 42 of Set 8 | Clyde River
# Processing Record 43 of Set 8 | Sistranda
# Processing Record 44 of Set 8 | Pullman
# Processing Record 45 of Set 8 | Kalmunai
# City not found. Skipping...
# Processing Record 46 of Set 8 | Iguape
# Processing Record 47 of Set 8 | Innisfail
# Processing Record 48 of Set 8 | Lagoa
# Processing Record 49 of Set 8 | Santa Cruz
# City not found. Skipping...
# Processing Record 50 of Set 8 | Mbini
# City not found. Skipping...
# Processing Record 1 of Set 9 | Huron
# Processing Record 2 of Set 9 | Jining
# Processing Record 3 of Set 9 | Walvis Bay
# Processing Record 4 of Set 9 | Itaituba
# Processing Record 5 of Set 9 | Birsk
# Processing Record 6 of Set 9 | Burnie
# Processing Record 7 of Set 9 | Selty
# Processing Record 8 of Set 9 | Ballina
# Processing Record 9 of Set 9 | Krasnoarmeysk
# Processing Record 10 of Set 9 | Okhotsk
# Processing Record 11 of Set 9 | Barzas
# Processing Record 12 of Set 9 | Huilong
# Processing Record 13 of Set 9 | Cradock
# Processing Record 14 of Set 9 | Ferkessedougou
# Processing Record 15 of Set 9 | Sisophon
# Processing Record 16 of Set 9 | Botwood
# Processing Record 17 of Set 9 | Da Lat
# Processing Record 18 of Set 9 | Kolyvan
# Processing Record 19 of Set 9 | Pisco
# Processing Record 20 of Set 9 | Severodvinsk
# Processing Record 21 of Set 9 | Sawtell
# Processing Record 22 of Set 9 | Nurota
# City not found. Skipping...
# Processing Record 23 of Set 9 | Alvaraes
# City not found. Skipping...
# Processing Record 24 of Set 9 | Villaviciosa
# City not found. Skipping...
# City not found. Skipping...
# Processing Record 25 of Set 9 | Coquimbo
# Processing Record 26 of Set 9 | Togur
# Processing Record 27 of Set 9 | Beira
# Processing Record 28 of Set 9 | Sisian
# Processing Record 29 of Set 9 | Sansepolcro
# Processing Record 30 of Set 9 | Campo Formoso
# Processing Record 31 of Set 9 | Svetlaya
# Processing Record 32 of Set 9 | Camacha
# Processing Record 33 of Set 9 | Tuljapur
# Processing Record 34 of Set 9 | Chivay
# Processing Record 35 of Set 9 | Halifax
# Processing Record 36 of Set 9 | Eshowe
# Processing Record 37 of Set 9 | Minsk
# Processing Record 38 of Set 9 | Rincon
# Processing Record 39 of Set 9 | Chifeng
# Processing Record 40 of Set 9 | Hauterive
# City not found. Skipping...
# Processing Record 41 of Set 9 | Sulangan
# City not found. Skipping...
# Processing Record 42 of Set 9 | Merauke
# Processing Record 43 of Set 9 | Yebaishou
# Processing Record 44 of Set 9 | Mata
# Processing Record 45 of Set 9 | Sibolga
# Processing Record 46 of Set 9 | Podgornoye
# Processing Record 47 of Set 9 | Balakhninskiy
# Processing Record 48 of Set 9 | Mwingi
# Processing Record 49 of Set 9 | Kropotkin
# City not found. Skipping...
# Processing Record 50 of Set 9 | Bulawayo
# Processing Record 1 of Set 10 | Bubaque
# Processing Record 2 of Set 10 | Davila
# Processing Record 3 of Set 10 | Bristol
# Processing Record 4 of Set 10 | Zhezkazgan
# Processing Record 5 of Set 10 | Coihaique
# City not found. Skipping...
# Processing Record 6 of Set 10 | Broken Hill
# Processing Record 7 of Set 10 | Moscow
# Processing Record 8 of Set 10 | Inuvik
# Processing Record 9 of Set 10 | Skoczow
# Processing Record 10 of Set 10 | Nabire
# Processing Record 11 of Set 10 | Anadyr
# Processing Record 12 of Set 10 | Talnakh
# Processing Record 13 of Set 10 | Mindelo
# Processing Record 14 of Set 10 | Majene
# Processing Record 15 of Set 10 | Dong Hoi
# Processing Record 16 of Set 10 | Nemuro
# Processing Record 17 of Set 10 | Altay
# Processing Record 18 of Set 10 | Emba
# Processing Record 19 of Set 10 | Wajid
# Processing Record 20 of Set 10 | Hanyang
# Processing Record 21 of Set 10 | Husavik
# Processing Record 22 of Set 10 | Bunog
# Processing Record 23 of Set 10 | Saint Anthony
# Processing Record 24 of Set 10 | Teahupoo
# Processing Record 25 of Set 10 | Wapakoneta
# City not found. Skipping...
# Processing Record 26 of Set 10 | Leh
# City not found. Skipping...
# Processing Record 27 of Set 10 | Toora-Khem
# Processing Record 28 of Set 10 | Mayumba
# Processing Record 29 of Set 10 | Bonthe
# City not found. Skipping...
# Processing Record 30 of Set 10 | Sandwick
# Processing Record 31 of Set 10 | Kijang
# Processing Record 32 of Set 10 | Khipro
# Processing Record 33 of Set 10 | Lahaina
# Processing Record 34 of Set 10 | Pointe-Noire
# City not found. Skipping...
# Processing Record 35 of Set 10 | Saint-Marc-des-Carrieres
# Processing Record 36 of Set 10 | Hwange
# Processing Record 37 of Set 10 | Antalaha
# Processing Record 38 of Set 10 | Novyy Urgal
# Processing Record 39 of Set 10 | Lambayeque
# Processing Record 40 of Set 10 | Canchungo
# Processing Record 41 of Set 10 | Lagdo
# Processing Record 42 of Set 10 | Amurzet
# Processing Record 43 of Set 10 | Ahipara
# Processing Record 44 of Set 10 | Perigueux
# Processing Record 45 of Set 10 | Praia
# Processing Record 46 of Set 10 | Mantua
# City not found. Skipping...
# Processing Record 47 of Set 10 | Angoche
# Processing Record 48 of Set 10 | Juticalpa
# City not found. Skipping...
# Processing Record 49 of Set 10 | Qeshm
# Processing Record 50 of Set 10 | Atmakur
# Processing Record 1 of Set 11 | Aswan
# Processing Record 2 of Set 11 | Kangaatsiaq
# Processing Record 3 of Set 11 | Quipapa
# Processing Record 4 of Set 11 | Preobrazheniye
# Processing Record 5 of Set 11 | Kozhva
# Processing Record 6 of Set 11 | Vostok
# Processing Record 7 of Set 11 | Virbalis
# Processing Record 8 of Set 11 | Manaia
# Processing Record 9 of Set 11 | Khani
# Processing Record 10 of Set 11 | Cerqueira Cesar
# Processing Record 11 of Set 11 | Northam
# Processing Record 12 of Set 11 | Clearlake
# Processing Record 13 of Set 11 | Farafangana
# Processing Record 14 of Set 11 | Kamyshin
# Processing Record 15 of Set 11 | Itarema
# Processing Record 16 of Set 11 | Suleja
# Processing Record 17 of Set 11 | Ahuimanu
# Processing Record 18 of Set 11 | Mahibadhoo
# Processing Record 19 of Set 11 | Beringovskiy
# Processing Record 20 of Set 11 | Artyom
# Processing Record 21 of Set 11 | Hailar
# Processing Record 22 of Set 11 | Kulhudhuffushi
# Processing Record 23 of Set 11 | Conde
# Processing Record 24 of Set 11 | Atbasar
# Processing Record 25 of Set 11 | Kapit
# Processing Record 26 of Set 11 | Ulcinj
# Processing Record 27 of Set 11 | Srivardhan
# Processing Record 28 of Set 11 | Santa Lucia
# Processing Record 29 of Set 11 | Pitkyaranta
# Processing Record 30 of Set 11 | Gizo
# Processing Record 31 of Set 11 | Shangrao
# Processing Record 32 of Set 11 | Sulechow
# Processing Record 33 of Set 11 | Gazanjyk
# Processing Record 34 of Set 11 | Havre-Saint-Pierre
# Processing Record 35 of Set 11 | Merrill
# City not found. Skipping...
# Processing Record 36 of Set 11 | Newton Stewart
# City not found. Skipping...
# Processing Record 37 of Set 11 | Veraval
# Processing Record 38 of Set 11 | Nelson Bay
# City not found. Skipping...
# Processing Record 39 of Set 11 | Englewood
# Processing Record 40 of Set 11 | Bitam
# Processing Record 41 of Set 11 | Kralendijk
# City not found. Skipping...
# Processing Record 42 of Set 11 | Flinders
# Processing Record 43 of Set 11 | Chekhov
# Processing Record 44 of Set 11 | Brae
# City not found. Skipping...
# Processing Record 45 of Set 11 | Te Anau

# %% [markdown]
# ### Convert Raw Data to DataFrame
# * Export the city data into a .csv.
# * Display the DataFrame

# %%
wdf = pd.DataFrame({'City':ct,'Cloudiness':cloud,'Country':country,'Date':dt,'Humidity':hum,
                   'Lat':lat, 'Lng':lng, 'Max Temp':maxt, 'Wind Speed':winsp})
wdf.to_csv('output/data.csv')
wdf.head()
# Out:
#             City  Cloudiness Country        Date  Humidity    Lat     Lng  \
# 0      busselton         100      AU  1562901826        56 -33.64  115.35
# 1         bethel          75      US  1562901826        68  60.79 -161.76
# 2  katima mulilo           4      NA  1562901826        42 -17.50   24.28
# 3           sola          81      TZ  1562901827        69  -3.17   33.80
# 4      saskylakh          67      RU  1562901827        46  71.97  114.09
#
#    Max Temp  Wind Speed
# 0     61.00        7.29
# 1     69.80       11.41
# 2     42.80        1.12
# 3     62.28        6.62
# 4     58.67       15.08

# %% [markdown]
# ### Plotting the Data
# * Use proper labeling of the plots using plot titles (including date of analysis) and axes labels.
# * Save the plotted figures as .pngs.

# %% [markdown]
# #### Latitude vs. Temperature Plot

# %%
plt.scatter(wdf['Lat'],wdf['Max Temp'],edgecolor='black',alpha=0.75)
plt.title(f"City Latitude vs. Max Temperature ({datetime.today().strftime('%m/%d/%y')})")
plt.xlabel('Latitude')
plt.ylabel('Max Temperature (F)')
plt.grid()
plt.savefig("output/lat_temp.png")
plt.show()

# %% [markdown]
# #### Latitude vs. Humidity Plot

# %%
plt.scatter(wdf['Lat'],wdf['Humidity'],edgecolor='black',alpha=0.75)
plt.title(f"City Latitude vs. Humidity ({datetime.today().strftime('%m/%d/%y')})")
plt.xlabel('Latitude')
plt.ylabel('Humidity (%)')
plt.grid()
plt.ylim(0,100)
plt.savefig("output/lat_hum.png")
plt.show()

# %% [markdown]
# #### Latitude vs. Cloudiness Plot

# %%
plt.scatter(wdf['Lat'],wdf['Cloudiness'],edgecolor='black',alpha=0.75)
plt.title(f"City Latitude vs. Cloudiness ({datetime.today().strftime('%m/%d/%y')})")
plt.xlabel('Latitude')
plt.ylabel('Cloudiness (%)')
plt.grid()
plt.savefig("output/lat_cloud.png")
plt.show()

# %% [markdown]
# #### Latitude vs. Wind Speed Plot

# %%
plt.scatter(wdf['Lat'],wdf['Wind Speed'],edgecolor='black',alpha=0.75)
plt.title(f"City Latitude vs. Wind Speed ({datetime.today().strftime('%m/%d/%y')})")
plt.xlabel('Latitude')
plt.ylabel('Wind Speeed (mph)')
plt.grid()
plt.savefig("output/lat_wind.png")
plt.show()
